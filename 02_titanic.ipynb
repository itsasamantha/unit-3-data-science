# %% [markdown]
# # Titanic Tabulation

# %% [markdown]
# The Titanic is a ship that set sail in 1912 and sank a few days after its departure. From April 10, 1912 to April 15, 1912, the Titanic was sailig for a mere 5 days. This notebook analyzes questions that arise from the

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
titanic_df = pd.read_csv('titanic_passengers.csv')

# %% [markdown]
# ## How many passengers survived.

# %%
print(titanic_df['Survived'].value_counts())
survived_count = titanic_df['Survived'].value_counts()

labels = 'Died', 'Survived'
sizes = survived_count

fig, ax = plt.subplots()
ax.pie(sizes, labels=labels, autopct='%1.1f%%', colors = ['LightSteelBlue', 'LightSlateGrey'], shadow=True, startangle=80)
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64
# ([<matplotlib.patches.Wedge at 0x1557ca0e0>,
#   <matplotlib.patches.Wedge at 0x1557a7730>],
#  [Text(-1.0801215296382067, -0.20817656259055836, 'Died'),
#   Text(1.0801216107050715, 0.20817614197568876, 'Survived')],
#  [Text(-0.5891571979844764, -0.11355085232212273, '61.6%'),
#   Text(0.5891572422027662, 0.1135506228958302, '38.4%')])

# %% [markdown]
# As seen in the pie chart above 38.4% of the titanic passengers survived. This percent is 342 people out of the 891 total people.

# %% [markdown]
# # How many people embarked from Queenstown

# %%
print(titanic_df['Embarked'].value_counts())
embarked_place = titanic_df['Embarked'].value_counts()

labels = 'Southampton', 'Cherbourg','Queenstown'
sizes = embarked_place

fig, ax = plt.subplots()
ax.pie(sizes, labels=labels, autopct='%1.1f%%', colors = ['LightSteelBlue', 'LightSlateGrey','SlateGrey'], shadow=True, startangle=80)
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64
# ([<matplotlib.patches.Wedge at 0x155a002b0>,
#   <matplotlib.patches.Wedge at 0x1559a28f0>,
#   <matplotlib.patches.Wedge at 0x155a01420>],
#  [Text(-0.9488261894350669, -0.5565328941240858, 'Southampton'),
#   Text(1.0634903578194281, 0.2810484990621811, 'Cherbourg'),
#   Text(0.47513054684331785, 0.9920942311375315, 'Queenstown')],
#  [Text(-0.5175415578736728, -0.30356339679495586, '72.4%'),
#   Text(0.580085649719688, 0.15329918130664422, '18.9%'),
#   Text(0.25916211645999154, 0.541142307893199, '8.7%')])

# %% [markdown]
# This graph shows the percentages of people embarking from each point. It shows that the least ,77/889 (two were not recorded), people embarked from Queenstown.

# %% [markdown]
# ## Were passengers who paid for expensive tickets( over 50 pounds) more likely to survive?

# %%
# importing package 
import numpy as np 

expensive_fares = titanic_df[titanic_df['Fare'] > 50]
expensive_survival = expensive_fares['Survived'].value_counts(normalize=True)

cheap_fares = titanic_df[titanic_df['Fare'] <= 50]
cheap_survival = cheap_fares['Survived'].value_counts(normalize=True)


print(cheap_survival)
print(expensive_survival)
# create data 
x = np.arange(2) 
y1 = [0.68125, 0.31875]
y2 = [0.318741,0.681259] 
width = 0.2

# plot data in grouped manner of bar type 
plt.figure(figsize=(10, 6))
plt.bar(x-0.2, y1, width, color='LightSteelBlue') 
plt.bar(x, y2, width, color='LightSlateGrey') 
plt.xticks(x, ['Lived', 'Died']) 
plt.xlabel("Survival") 
plt.ylabel("Frequency") 
plt.legend(["Expensive", "Cheap"]) 
plt.show()
# Out:
# Survived
# 0    0.681259
# 1    0.318741
# Name: proportion, dtype: float64
# Survived
# 1    0.68125
# 0    0.31875
# Name: proportion, dtype: float64

# %% [markdown]
# This graph show the people that people that lived were more likely to live than die and that those who purchased cheap tickets were more likely to die than survive.

# %% [markdown]
# ## Did the Embark location change the fare price

# %%
grouped = titanic_df.groupby("Embarked")["Fare"].value_counts()
# grouped = titanic_df.groupby(['Embarked', 'Fare']).sum().reset_index()

# IIIIIIIIIIIDDDDDDDDKKKKKKKK

# grouped_q = grouped["Embarked"] == "Q"
# grouped_s = grouped["Embarked"] == "S"
# grouped_c = grouped["Embarked"] == "C"
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Library/Python/3.10/lib/python/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Embarked'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[182], line 3
#       1 grouped = titanic_df.groupby("Embarked")["Fare"].value_counts()
#       2 # grouped = titanic_df.groupby(['Embarked', 'Fare']).sum().reset_index()
# ----> 3 grouped_q = grouped["Embarked"] == "Q"
#
# File ~/Library/Python/3.10/lib/python/site-packages/pandas/core/series.py:1121, in Series.__getitem__(self, key)
#    1118     return self._values[key]
#    1120 elif key_is_scalar:
# -> 1121     return self._get_value(key)
#    1123 # Convert generator to list before going through hashable part
#    1124 # (We will iterate through the generator there to check for slices)
#    1125 if is_iterator(key):
#
# File ~/Library/Python/3.10/lib/python/site-packages/pandas/core/series.py:1237, in Series._get_value(self, label, takeable)
#    1234     return self._values[label]
#    1236 # Similar to Index.get_value, but we do not fall back to positional
# -> 1237 loc = self.index.get_loc(label)
#    1239 if is_integer(loc):
#    1240     return self._values[loc]
#
# File ~/Library/Python/3.10/lib/python/site-packages/pandas/core/indexes/multi.py:3040, in MultiIndex.get_loc(self, key)
#    3037     return mask
#    3039 if not isinstance(key, tuple):
# -> 3040     loc = self._get_level_indexer(key, level=0)
#    3041     return _maybe_to_slice(loc)
#    3043 keylen = len(key)
#
# File ~/Library/Python/3.10/lib/python/site-packages/pandas/core/indexes/multi.py:3391, in MultiIndex._get_level_indexer(self, key, level, indexer)
#    3388         return slice(i, j, step)
#    3390 else:
# -> 3391     idx = self._get_loc_single_level_index(level_index, key)
#    3393     if level > 0 or self._lexsort_depth == 0:
#    3394         # Desired level is not sorted
#    3395         if isinstance(idx, slice):
#    3396             # test_get_loc_partial_timestamp_multiindex
#
# File ~/Library/Python/3.10/lib/python/site-packages/pandas/core/indexes/multi.py:2980, in MultiIndex._get_loc_single_level_index(self, level_index, key)
#    2978     return -1
#    2979 else:
# -> 2980     return level_index.get_loc(key)
#
# File ~/Library/Python/3.10/lib/python/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Embarked'
